# %% [markdown]
# ## Installation de spark-cluster & findspark, pyspark

# %%
# innstall java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# install spark (change the version number if needed)
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz

# unzip the spark file to the current folder
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz

# set your spark folder to your system path environment. 
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"


# install findspark using pip
# !pip install -q findspark

# install pyspark
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspark
#   Downloading pyspark-3.3.1.tar.gz (281.4 MB)
#      |████████████████████████████████| 281.4 MB 36 kB/s
# Collecting py4j==0.10.9.5
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 49.5 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.3.1-py2.py3-none-any.whl size=281845513 sha256=973931576b313f7a59312651f039cdba1ef3a295a6f524f8eba78b45741d9799
#   Stored in directory: /root/.cache/pip/wheels/42/59/f5/79a5bf931714dcd201b26025347785f087370a10a3329a899c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.5 pyspark-3.3.1

# %% [markdown]
# # importation et initialisation de Spark

# %%
import findspark 
findspark.init()

# %% [markdown]
# ## importer PySpark et initialiser SparkContext

# %%
from pyspark import SparkContext, SparkConf
conf = SparkConf().setAppName("actions").setMaster("local[*]")
sc = SparkContext(conf = conf)

# %% [markdown]
# ## Appliquer la Transformation MAP()
# ![image.png](attachment:image.png)

# %%
num = sc.parallelize([2,9,7,4,3,1])
num.map(lambda a : a*4).collect()
# Out:
# [8, 36, 28, 16, 12, 4]

# %% [markdown]
# ## Application la transformation flatMap()
# ![image.png](attachment:image.png)

# %%
textRdd=sc.textFile('text_ex1.txt')
wordRdd=textRdd.flatMap(lambda x: x.split(" "))
wordRdd.collect()
# Out:
# ['Duis',
#  'sodales',
#  'odio',
#  'eget',
#  'nunc',
#  'cursus,',
#  'iaculis',
#  'rutrum',
#  'metus',
#  'consectetur.',
#  'Praesent',
#  'non',
#  'sem',
#  'urna.',
#  'Aliquam',
#  'nec',
#  'efficitur',
#  'justo,',
#  'egestas',
#  'blandit',
#  'sem.',
#  'Curabitur',
#  'est',
#  'mi,',
#  'imperdiet',
#  'in',
#  'mauris',
#  'vel,',
#  'condimentum',
#  'hendrerit',
#  'lorem.',
#  'Donec',
#  'nec',
#  'neque',
#  'nibh.',
#  'Suspendisse',
#  'potenti.',
#  'Praesent',
#  'eget',
#  'venenatis',
#  'magna.',
#  'Curabitur',
#  'non',
#  'rutrum',
#  'velit,',
#  'eu',
#  'aliquam',
#  'nulla.',
#  'Cras',
#  'est',
#  'sapien,',
#  'dictum',
#  'quis',
#  'varius',
#  'in,',
#  'mattis',
#  'eleifend',
#  'velit.',
#  'Etiam',
#  'ut',
#  'fermentum',
#  'diam.',
#  'Phasellus',
#  'maximus',
#  'velit',
#  'non',
#  'sollicitudin',
#  'aliquam.',
#  'Vestibulum',
#  'vulputate',
#  'vel',
#  'quam',
#  'id',
#  'imperdiet.',
#  'Maecenas',
#  'luctus',
#  'lectus',
#  'id',
#  'diam',
#  'cursus',
#  'finibus.',
#  '',
#  'Cras',
#  'scelerisque',
#  'mi',
#  'quis',
#  'odio',
#  'euismod,',
#  'pellentesque',
#  'eleifend',
#  'elit',
#  'interdum.',
#  'Proin',
#  'tellus',
#  'arcu,',
#  'scelerisque',
#  'et',
#  'urna',
#  'nec,',
#  'cursus',
#  'tristique',
#  'mi.',
#  'Nunc',
#  'sodales,',
#  'eros',
#  'ac',
#  'commodo',
#  'vehicula,',
#  'sapien',
#  'dolor',
#  'luctus',
#  'nunc,',
#  'nec',
#  'consectetur',
#  'tellus',
#  'nisi',
#  'eget',
#  'nisl.',
#  'In',
#  'hac',
#  'habitasse',
#  'platea',
#  'dictumst.',
#  'In',
#  'tristique',
#  'facilisis',
#  'risus,',
#  'quis',
#  'consequat',
#  'enim',
#  'vehicula',
#  'in.',
#  'Etiam',
#  'congue',
#  'quam',
#  'odio,',
#  'sed',
#  'dapibus',
#  'justo',
#  'faucibus',
#  'ac.',
#  'Ut',
#  'tristique',
#  'tellus',
#  'eros,',
#  'sed',
#  'posuere',
#  'ipsum',
#  'fermentum',
#  'nec.',
#  'Vivamus',
#  'Tempor',
#  'augue',
#  'dapibus',
#  'dolor',
#  'convallis,',
#  'a',
#  'dignissim',
#  'erat',
#  'lobortis.',
#  'Cras',
#  'dapibus,',
#  'justo',
#  'fermentum',
#  'sagittis',
#  'gravida,',
#  'dolor',
#  'turpis',
#  'tempus',
#  'turpis,',
#  'id',
#  'tincidunt',
#  'mi',
#  'erat',
#  'eget',
#  'turpis.',
#  'Integer',
#  'vitae',
#  'dui',
#  'laoreet',
#  'arcu',
#  'tempus',
#  'facilisis',
#  'eget',
#  'in',
#  'enim.',
#  'Maecenas',
#  'ornare',
#  'justo',
#  'eget',
#  'nisi',
#  'consectetur',
#  'aliquet.',
#  'Quisque',
#  'a',
#  'arcu',
#  'risus.',
#  'Donec',
#  'risus',
#  'risus,',
#  'malesuada',
#  'nec',
#  'ex',
#  'id,',
#  'commodo',
#  'volutpat',
#  'dolor.',
#  'Suspendisse',
#  'eleifend',
#  'fringilla',
#  'justo,',
#  'sit',
#  'amet',
#  'dapibus',
#  'ligula',
#  'dapibus',
#  'a.',
#  'Nulla',
#  'consequat',
#  'vestibulum',
#  'nulla,',
#  'sit',
#  'amet',
#  'tempor',
#  'nunc',
#  'porttitor',
#  'non.',
#  'Suspendisse',
#  'hendrerit',
#  'lobortis',
#  'dapibus.',
#  '',
#  'In',
#  'vel',
#  'mi',
#  'sed',
#  'nibh',
#  'gravida',
#  'laoreet.',
#  'Nunc',
#  'dictum,',
#  'augue',
#  'ac',
#  'semper',
#  'elementum,',
#  'magna',
#  'dui',
#  'hendrerit',
#  'dui,',
#  'vel',
#  'tempus',
#  'dolor',
#  'orci',
#  'quis',
#  'nunc.',
#  'Proin',
#  'hendrerit',
#  'nisl',
#  'eget',
#  'pulvinar',
#  'mollis.',
#  'Donec',
#  'a',
#  'neque',
#  'lectus.',
#  'Sed',
#  'blandit',
#  'gravida',
#  'egestas.',
#  'Suspendisse',
#  'tortor',
#  'massa,',
#  'viverra',
#  'ut',
#  'turpis',
#  'vel,',
#  'tincidunt',
#  'fringilla',
#  'sem.',
#  'Integer',
#  'sed',
#  'luctus',
#  'mauris.',
#  'Vestibulum',
#  'posuere,',
#  'eros',
#  'nec',
#  'pulvinar',
#  'sollicitudin,',
#  'nisl',
#  'est',
#  'mattis',
#  'sapien,',
#  'at',
#  'accumsan',
#  'leo',
#  'sapien',
#  'in',
#  'justo.',
#  'Vestibulum',
#  'tristique',
#  'pellentesque',
#  'odio',
#  'et',
#  'dictum.',
#  'Aliquam',
#  'nulla',
#  'metus,',
#  'lacinia',
#  'iaculis',
#  'risus',
#  'non,',
#  'volutpat',
#  'ullamcorper',
#  'mauris.',
#  'Morbi',
#  'ante',
#  'augue,',
#  'volutpat',
#  'ac',
#  'porta',
#  'condimentum,',
#  'consectetur',
#  'a',
#  'dui.',
#  'Duis',
#  'ultrices',
#  'ut',
#  'nunc',
#  'ut',
#  'tempus.',
#  'Nullam',
#  'eget',
#  'erat',
#  'lectus.',
#  'Nullam',
#  'mollis',
#  'finibus',
#  'dignissim.',
#  'Nunc',
#  'tempor,',
#  'justo',
#  'sit',
#  'amet',
#  'accumsan',
#  'cursus,',
#  'nunc',
#  'lacus',
#  'semper',
#  'enim,',
#  'posuere',
#  'finibus',
#  'purus',
#  'enim',
#  'sit',
#  'amet',
#  'purus.',
#  '',
#  'Integer',
#  'ornare,',
#  'augue',
#  'fringilla',
#  'viverra',
#  'eleifend,',
#  'ligula',
#  'leo',
#  'fringilla',
#  'metus,',
#  'eget',
#  'ullamcorper',
#  'risus',
#  'erat',
#  'eget',
#  'orci.',
#  'Ut',
#  'lectus',
#  'nisl,',
#  'mollis',
#  'at',
#  'odio',
#  'eu,',
#  'dictum',
#  'egestas',
#  'leo.',
#  'Suspendisse',
#  'scelerisque',
#  'convallis',
#  'mi,',
#  'eu',
#  'tempor',
#  'nibh',
#  'euismod',
#  'ac.',
#  'Nulla',
#  'pharetra',
#  'ullamcorper',
#  'augue',
#  'at',
#  'laoreet.',
#  'Donec',
#  'sit',
#  'amet',
#  'tincidunt',
#  'risus,',
#  'ut',
#  'luctus',
#  'ipsum.',
#  'Nullam',
#  'vel',
#  'libero',
#  'dapibus,',
#  'pharetra',
#  'tellus',
#  'id,',
#  'aliquet',
#  'eros.',
#  'Pellentesque',
#  'in',
#  'pellentesque',
#  'justo.',
#  'Integer',
#  'lectus',
#  'nunc,',
#  'bibendum',
#  'sit',
#  'amet',
#  'dui',
#  'non,',
#  'sagittis',
#  'suscipit',
#  'sem.',
#  'In',
#  'gravida',
#  'ante',
#  'vitae',
#  'lorem',
#  'hendrerit,',
#  'non',
#  'accumsan',
#  'metus',
#  'posuere.',
#  'In',
#  'vitae',
#  'leo',
#  'id',
#  'libero',
#  'condimentum',
#  'malesuada.',
#  'Aliquam',
#  'vitae',
#  'lacus',
#  'suscipit,',
#  'ullamcorper',
#  'nulla',
#  'blandit,',
#  'gravida',
#  'erat.',
#  'Proin',
#  'eros',
#  'mauris,',
#  'accumsan',
#  'vel',
#  'sapien',
#  'eu,',
#  'pretium',
#  'tristique',
#  'sem.',
#  'Fusce',
#  'sit',
#  'amet',
#  'tempus',
#  'leo,',
#  'in',
#  'aliquet',
#  'lorem.',
#  'Aliquam',
#  'erat',
#  'volutpat.',
#  'Aenean',
#  'volutpat',
#  'justo',
#  'et',
#  'felis',
#  'accumsan',
#  'rutrum.',
#  'Aenean',
#  'malesuada',
#  'consequat',
#  'sem,',
#  'ac',
#  'euismod',
#  'est',
#  'faucibus',
#  'sed.',
#  '',
#  'Donec',
#  'lacus',
#  'nulla,',
#  'hendrerit',
#  'sed',
#  'gravida',
#  'consequat,',
#  'laoreet',
#  'eu',
#  'magna.',
#  'Nullam',
#  'faucibus,',
#  'dolor',
#  'quis',
#  'mattis',
#  'sollicitudin,',
#  'ex',
#  'sem',
#  'sollicitudin',
#  'nisl,',
#  'vel',
#  'aliquam',
#  'metus',
#  'ex',
#  'eget',
#  'nisi.',
#  'Morbi',
#  'sed',
#  'varius',
#  'nulla,',
#  'et',
#  'dictum',
#  'ex.',
#  'Praesent',
#  'eget',
#  'quam',
#  'condimentum,',
#  'volutpat',
#  'arcu',
#  'vitae,',
#  'consequat',
#  'mauris.',
#  'Sed',
#  'semper',
#  'arcu',
#  'eu',
#  'dolor',
#  'hendrerit',
#  'laoreet.',
#  'Nullam',
#  'vestibulum',
#  'risus',
#  'a',
#  'sagittis',
#  'tempus.',
#  'Phasellus',
#  'viverra',
#  'quam',
#  'mollis',
#  'nunc',
#  'iaculis,',
#  'non',
#  'euismod',
#  'tortor',
#  'rhoncus.',
#  'Quisque',
#  'enim',
#  'nisi,',
#  'efficitur',
#  'ut',
#  'odio',
#  'at,',
#  'venenatis',
#  'consectetur',
#  'lorem.',
#  'Suspendisse',
#  'potenti.',
#  'Suspendisse',
#  'potenti.',
#  'Aenean',
#  'id',
#  'malesuada',
#  'sem,',
#  'placerat',
#  'porttitor',
#  'dolor.',
#  '',
#  'Integer',
#  'efficitur',
#  'tristique',
#  'velit,',
#  'nec',
#  'egestas',
#  'massa',
#  'ultrices',
#  'quis.',
#  'Suspendisse',
#  'ultrices',
#  'mattis',
#  'urna.',
#  'Proin',
#  'urna',
#  'est,',
#  'bibendum',
#  'at',
#  'vulputate',
#  'vel,',
#  'scelerisque',
#  'vitae',
#  'tortor.',
#  'Quisque',
#  'lacinia',
#  'neque',
#  'in',
#  'pharetra',
#  'posuere.',
#  'Nulla',
#  'quis',
#  'nulla',
#  'nisl.',
#  'Quisque',
#  'sed',
#  'nulla',
#  'tincidunt,',
#  'gravida',
#  'dolor',
#  'at,',
#  'malesuada',
#  'nisi.',
#  'Proin',
#  'scelerisque,',
#  'lorem',
#  'non',
#  'suscipit',
#  'convallis,',
#  'risus',
#  'diam',
#  'cursus',
#  'augue,',
#  'eget',
#  'semper',
#  'neque',
#  'augue',
#  'bibendum',
#  'velit.',
#  'Fusce',
#  'eu',
#  'aliquet',
#  'nisi.',
#  'Phasellus',
#  'semper',
#  'orci',
#  'nec',
#  'justo',
#  'pulvinar,',
#  'id',
#  'porta',
#  'sapien',
#  'malesuada.',
#  'Ut',
#  'bibendum',
#  'a',
#  'ante',
#  'tempor',
#  'fringilla.',
#  'Nullam',
#  'tincidunt',
#  'laoreet',
#  'elit',
#  'et',
#  'vestibulum.',
#  'Suspendisse',
#  'diam',
#  'erat,',
#  'convallis',
#  'id',
#  'porttitor',
#  'varius,',
#  'scelerisque',
#  'quis',
#  'nulla.',
#  'Proin',
#  'ut',
#  'fermentum',
#  'lacus.',
#  'Pellentesque',
#  'habitant',
#  'morbi',
#  'tristique',
#  'senectus',
#  'et',
#  'netus',
#  'et',
#  'malesuada',
#  'fames',
#  'ac',
#  'turpis',
#  'egestas.',
#  '',
#  'In',
#  'sit',
#  'amet',
#  'interdum',
#  'orci,',
#  'et',
#  'consectetur',
#  'est.',
#  'In',
#  'hac',
#  'habitasse',
#  'platea',
#  'dictumst.',
#  'Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet,',
#  'consectetur',
#  'adipiscing',
#  'elit.',
#  'Phasellus',
#  'sollicitudin',
#  'aliquam',
#  'sem,',
#  'non',
#  'hendrerit',
#  'mi',
#  'scelerisque',
#  'sed.',
#  'Maecenas',
#  'augue',
#  'mi,',
#  'blandit',
#  'sit',
#  'amet',
#  'hendrerit',
#  'at,',
#  'cursus',
#  'at',
#  'lectus.',
#  'Sed',
#  'malesuada',
#  'consectetur',
#  'eleifend.',
#  'Ut',
#  'in',
#  'elit',
#  'molestie,',
#  'gravida',
#  'velit',
#  'eu,',
#  'luctus',
#  'risus.',
#  'Quisque',
#  'sed',
#  'sem',
#  'eu',
#  'ipsum',
#  'tincidunt',
#  'ultricies',
#  'quis',
#  'et',
#  'ligula.',
#  'Cras',
#  'feugiat',
#  'gravida',
#  'venenatis.',
#  'Praesent',
#  'gravida',
#  'turpis',
#  'vel',
#  'fermentum',
#  'vulputate.',
#  'In',
#  'molestie,',
#  'massa',
#  'posuere',
#  'volutpat',
#  'ultrices,',
#  'nulla',
#  'ipsum',
#  'blandit',
#  'justo,',
#  'sed',
#  'interdum',
#  'nibh',
#  'metus',
#  'vitae',
#  'risus.',
#  'Donec',
#  'eget',
#  'ipsum',
#  'ipsum.',
#  'Nullam',
#  'non',
#  'odio',
#  'et',
#  'eros',
#  'tincidunt',
#  'hendrerit.',
#  'Etiam',
#  'elit',
#  'sapien,',
#  'sodales',
#  'id',
#  'eros',
#  'id,',
#  'rutrum',
#  'vulputate',
#  'magna.',
#  'Interdum',
#  'et',
#  'malesuada',
#  'fames',
#  'ac',
#  'ante',
#  'ipsum',
#  'primis',
#  'in',
#  'faucibus.',
#  'Phasellus',
#  'purus',
#  'elit,',
#  'iaculis',
#  'sit',
#  'amet',
#  'eros',
#  'eu,',
#  'feugiat',
#  'molestie',
#  'leo.',
#  '',
#  'Nunc',
#  'eget',
#  'consequat',
#  'sapien.',
#  'Fusce',
#  'gravida',
#  'sapien',
#  'ut',
#  'nisl',
#  'porttitor',
#  'pharetra.',
#  'Duis',
#  'ultrices',
#  'pretium',
#  'magna',
#  'nec',
#  'malesuada.',
#  'Etiam',
#  'id',
#  'blandit',
#  'ligula,',
#  'eu',
#  'molestie',
#  'libero.',
#  'Ut',
#  'varius',
#  'mauris',
#  'sit',
#  'amet',
#  'neque',
#  'auctor',
#  'luctus.',
#  'Nunc',
#  'id',
#  'varius',
#  'velit.',
#  'Donec',
#  'sit',
#  'amet',
#  'ante',
#  'leo.',
#  'Vivamus',
#  'mattis',
#  'neque',
#  'et',
#  'ultricies',
#  'accumsan.',
#  'Cras',
#  'pellentesque',
#  'felis',
#  'vitae',
#  'hendrerit',
#  'ullamcorper.',
#  'Donec',
#  'sit',
#  'amet',
#  'sapien',
#  'vel',
#  'ante',
#  'hendrerit',
#  'fringilla',
#  'non',
#  'ut',
#  'augue.',
#  '',
#  'Vivamus',
#  'lobortis',
#  'vestibulum',
#  'consectetur.',
#  'Donec',
#  'auctor',
#  'finibus',
#  'augue',
#  'sit',
#  'amet',
#  'hendrerit.',
#  'In',
#  'quis',
#  'nisi',
#  'quis',
#  'sapien',
#  'euismod',
#  'suscipit',
#  'sit',
#  'amet',
#  'non',
#  'turpis.',
#  'Proin',
#  'semper',
#  'pulvinar',
#  'vestibulum.',
#  'Suspendisse',
#  'velit',
#  'metus,',
#  'eleifend',
#  'vel',
#  'tortor',
#  'a,',
#  'sollicitudin',
#  'maximus',
#  'mauris.',
#  'Etiam',
#  'non',
#  'enim',
#  'ac',
#  'ex',
#  'dapibus',
#  'eleifend.',
#  'Cras',
#  'sed',
#  'pretium',
#  'est,',
#  'quis',
#  'fermentum',
#  'arcu.',
#  'Donec',
#  'in',
#  'diam',
#  'bibendum,',
#  'sodales',
#  'ex',
#  'vitae,',
#  'vulputate',
#  'dui.',
#  'Lorem',
#  'ipsum',
#  'dolor',
#  'sit',
#  'amet,',
#  'consectetur',
#  'adipiscing',
#  'elit.',
#  '',
#  'Sed',
#  'convallis',
#  'turpis',
#  'sed',
#  'lectus',
#  'elementum,',
#  'quis',
#  'interdum',
#  'odio',
#  'malesuada.',
#  'Donec',
#  'convallis',
#  'auctor',
#  'nunc,',
#  'nec',
#  'hendrerit',
#  'dolor',
#  'fermentum',
#  'vel.',
#  'Proin',
#  'semper',
#  'eget',
#  'ligula',
#  'non',
#  'luctus.',
#  'Integer',
#  'sed',
#  'feugiat',
#  'dui.',
#  'Quisque',
#  'in',
#  'ex',
#  'a',
#  'velit',
#  'tincidunt',
#  'pulvinar.',
#  'Morbi',
#  'tincidunt,',
#  'sapien',
#  'pharetra',
#  ...]

# %% [markdown]
# ## Application la transformation filter()
# ![image.png](attachment:image.png)

# %%
wordRdd.filter(lambda x : "c" in x).collect()
# Out:
# ['nunc',
#  'cursus,',
#  'iaculis',
#  'consectetur.',
#  'nec',
#  'efficitur',
#  'condimentum',
#  'Donec',
#  'nec',
#  'dictum',
#  'sollicitudin',
#  'Maecenas',
#  'luctus',
#  'lectus',
#  'cursus',
#  'scelerisque',
#  'arcu,',
#  'scelerisque',
#  'nec,',
#  'cursus',
#  'Nunc',
#  'ac',
#  'commodo',
#  'vehicula,',
#  'luctus',
#  'nunc,',
#  'nec',
#  'consectetur',
#  'hac',
#  'dictumst.',
#  'facilisis',
#  'consequat',
#  'vehicula',
#  'congue',
#  'faucibus',
#  'ac.',
#  'nec.',
#  'convallis,',
#  'tincidunt',
#  'arcu',
#  'facilisis',
#  'Maecenas',
#  'consectetur',
#  'arcu',
#  'Donec',
#  'nec',
#  'commodo',
#  'consequat',
#  'nunc',
#  'Nunc',
#  'dictum,',
#  'ac',
#  'orci',
#  'nunc.',
#  'Donec',
#  'lectus.',
#  'tincidunt',
#  'luctus',
#  'nec',
#  'sollicitudin,',
#  'accumsan',
#  'dictum.',
#  'lacinia',
#  'iaculis',
#  'ullamcorper',
#  'ac',
#  'condimentum,',
#  'consectetur',
#  'ultrices',
#  'nunc',
#  'lectus.',
#  'Nunc',
#  'accumsan',
#  'cursus,',
#  'nunc',
#  'lacus',
#  'ullamcorper',
#  'orci.',
#  'lectus',
#  'dictum',
#  'scelerisque',
#  'convallis',
#  'ac.',
#  'ullamcorper',
#  'Donec',
#  'tincidunt',
#  'luctus',
#  'lectus',
#  'nunc,',
#  'suscipit',
#  'accumsan',
#  'condimentum',
#  'lacus',
#  'suscipit,',
#  'ullamcorper',
#  'accumsan',
#  'Fusce',
#  'accumsan',
#  'consequat',
#  'ac',
#  'faucibus',
#  'Donec',
#  'lacus',
#  'consequat,',
#  'faucibus,',
#  'sollicitudin,',
#  'sollicitudin',
#  'dictum',
#  'condimentum,',
#  'arcu',
#  'consequat',
#  'arcu',
#  'nunc',
#  'iaculis,',
#  'rhoncus.',
#  'efficitur',
#  'consectetur',
#  'placerat',
#  'efficitur',
#  'nec',
#  'ultrices',
#  'ultrices',
#  'scelerisque',
#  'lacinia',
#  'tincidunt,',
#  'scelerisque,',
#  'suscipit',
#  'convallis,',
#  'cursus',
#  'Fusce',
#  'orci',
#  'nec',
#  'tincidunt',
#  'convallis',
#  'scelerisque',
#  'lacus.',
#  'senectus',
#  'ac',
#  'orci,',
#  'consectetur',
#  'hac',
#  'dictumst.',
#  'consectetur',
#  'adipiscing',
#  'sollicitudin',
#  'scelerisque',
#  'Maecenas',
#  'cursus',
#  'lectus.',
#  'consectetur',
#  'luctus',
#  'tincidunt',
#  'ultricies',
#  'ultrices,',
#  'Donec',
#  'tincidunt',
#  'ac',
#  'faucibus.',
#  'iaculis',
#  'Nunc',
#  'consequat',
#  'Fusce',
#  'ultrices',
#  'nec',
#  'auctor',
#  'luctus.',
#  'Nunc',
#  'Donec',
#  'ultricies',
#  'accumsan.',
#  'ullamcorper.',
#  'Donec',
#  'consectetur.',
#  'Donec',
#  'auctor',
#  'suscipit',
#  'sollicitudin',
#  'ac',
#  'arcu.',
#  'Donec',
#  'consectetur',
#  'adipiscing',
#  'convallis',
#  'lectus',
#  'Donec',
#  'convallis',
#  'auctor',
#  'nunc,',
#  'nec',
#  'luctus.',
#  'tincidunt',
#  'tincidunt,',
#  'facilisis',
#  'convallis',
#  'vehicula',
#  'ultrices',
#  'condimentum',
#  'facilisis',
#  'Donec',
#  'accumsan',
#  'facilisis',
#  'Maecenas',
#  'rhoncus',
#  'lacinia',
#  'commodo',
#  'lacus',
#  'tincidunt',
#  'facilisis.',
#  'sollicitudin',
#  'ultricies',
#  'Nunc',
#  'arcu',
#  'ac',
#  'auctor',
#  'scelerisque',
#  'nunc,',
#  'cursus',
#  'faucibus.',
#  'cursus',
#  'orci.',
#  'lacinia',
#  'arcu',
#  'congue.',
#  'vehicula',
#  'luctus',
#  'Donec',
#  'accumsan',
#  'iaculis',
#  'faucibus',
#  'vehicula',
#  'ac',
#  'consequat',
#  'efficitur.',
#  'ultrices',
#  'arcu,',
#  'accumsan',
#  'ultrices',
#  'consequat',
#  'congue.',
#  'iaculis',
#  'Donec',
#  'ac',
#  'nunc',
#  'vehicula,',
#  'ac',
#  'ultricies,',
#  'congue',
#  'vehicula.',
#  'placerat',
#  'lectus.',
#  'efficitur',
#  'Maecenas',
#  'tincidunt',
#  'commodo',
#  'ullamcorper',
#  'auctor',
#  'Donec',
#  'ac',
#  'faucibus',
#  'orci',
#  'commodo,',
#  'consequat',
#  'nec',
#  'consequat',
#  'tincidunt.',
#  'Nunc',
#  'vehicula',
#  'iaculis',
#  'dictum',
#  'taciti',
#  'sociosqu',
#  'conubia',
#  'inceptos',
#  'Fusce',
#  'tincidunt',
#  'facilisis',
#  'placerat.',
#  'nunc',
#  'consequat',
#  'tincidunt',
#  'arcu.',
#  'Maecenas',
#  'luctus',
#  'rhoncus',
#  'consequat.',
#  'Donec',
#  'placerat',
#  'accumsan,',
#  'auctor,',
#  'ullamcorper',
#  'ac',
#  'ultrices',
#  'iaculis',
#  'ullamcorper',
#  'scelerisque',
#  'auctor,',
#  'convallis',
#  'arcu.',
#  'ultricies',
#  'commodo.',
#  'Donec',
#  'lectus,',
#  'nunc',
#  'nec,',
#  'luctus',
#  'ac',
#  'consequat.',
#  'convallis.',
#  'consectetur',
#  'consectetur',
#  'ac',
#  'ac',
#  'ac',
#  'rhoncus',
#  'tincidunt.',
#  'facilisis,',
#  'lacinia',
#  'Donec',
#  'sollicitudin',
#  'sollicitudin',
#  'orci',
#  'faucibus',
#  'cursus',
#  'consectetur',
#  'tincidunt,',
#  'facilisis',
#  'dictum',
#  'nec',
#  'orci.',
#  'iaculis',
#  'lectus.',
#  'Orci',
#  'nascetur',
#  'ridiculus',
#  'nec',
#  'tincidunt',
#  'Donec',
#  'placerat',
#  'scelerisque,',
#  'nec',
#  'tincidunt',
#  'congue',
#  'arcu',
#  'sollicitudin,',
#  'tincidunt',
#  'nunc',
#  'lacinia',
#  'facilisis',
#  'ultricies.',
#  'ultricies',
#  'rhoncus.',
#  'rhoncus',
#  'arcu',
#  'ullamcorper',
#  'Fusce',
#  'ac.',
#  'efficitur',
#  'faucibus,',
#  'ac',
#  'lacinia',
#  'cursus',
#  'ullamcorper',
#  'cursus',
#  'dictum',
#  'cursus',
#  'iaculis',
#  'nec',
#  'auctor',
#  'Donec',
#  'consequat,',
#  'lacus',
#  'congue',
#  'commodo',
#  'facilisis',
#  'congue,',
#  'vehicula',
#  'ultricies',
#  'consectetur',
#  'ac',
#  'convallis',
#  'condimentum',
#  'ultrices',
#  'luctus',
#  'iaculis',
#  'vehicula',
#  'nec',
#  'dictum',
#  'tincidunt',
#  'orci.',
#  'ultrices',
#  'efficitur',
#  'facilisis.',
#  'ac',
#  'commodo',
#  'consectetur',
#  'faucibus',
#  'lacinia',
#  'luctus,',
#  'consectetur',
#  'orci.',
#  'Maecenas',
#  'efficitur',
#  'consequat.',
#  'convallis',
#  'efficitur',
#  'facilisis',
#  'placerat',
#  'vehicula',
#  'lectus',
#  'auctor',
#  'sollicitudin',
#  'ac',
#  'lacus.',
#  'efficitur,',
#  'Donec',
#  'placerat',
#  'Donec',
#  'rhoncus',
#  'lacinia',
#  'consectetur',
#  'lacinia.',
#  'Maecenas',
#  'ac',
#  'lacinia,',
#  'hac',
#  'dictumst.',
#  'efficitur.',
#  'Fusce',
#  'suscipit',
#  'nunc',
#  'tincidunt',
#  'dictum',
#  'lacus',
#  'Donec',
#  'iaculis',
#  'tincidunt.',
#  'ultricies',
#  'ac',
#  'suscipit',
#  'ultrices.',
#  'consectetur',
#  'placerat',
#  'ac',
#  'vehicula',
#  'tincidunt,',
#  'efficitur',
#  'lacus,',
#  'lacus',
#  'vehicula',
#  'nec,',
#  'tincidunt',
#  'ultrices.',
#  'nec',
#  'auctor',
#  'Donec',
#  'luctus',
#  'nec',
#  'rhoncus,',
#  'facilisis',
#  'condimentum',
#  'sollicitudin',
#  'ultricies',
#  'Maecenas',
#  'efficitur',
#  'ac,',
#  'tincidunt.',
#  'suscipit',
#  'Donec',
#  'lectus',
#  'efficitur',
#  'rhoncus',
#  'dictum',
#  'suscipit',
#  'luctus',
#  'luctus',
#  'facilisis',
#  'nec.',
#  'consequat.',
#  'lectus',
#  'lectus.',
#  'tincidunt',
#  'orci',
#  'lacinia',
#  'tincidunt',
#  'ullamcorper',
#  'congue',
#  'suscipit',
#  'condimentum',
#  'placerat.',
#  'vehicula',
#  'sollicitudin.',
#  'orci,',
#  'facilisis',
#  'Donec',
#  'ac',
#  'facilisis',
#  'Donec',
#  'tincidunt',
#  'congue',
#  'lacinia',
#  'nec',
#  'vehicula',
#  'nec',
#  'efficitur',
#  'condimentum,',
#  'efficitur',
#  'Donec',
#  'efficitur',
#  'faucibus',
#  'auctor.',
#  'rhoncus',
#  'arcu.',
#  'consectetur',
#  'iaculis',
#  'Nunc',
#  'vehicula',
#  'ac',
#  'facilisis',
#  'faucibus',
#  'lectus',
#  'Orci',
#  'nascetur',
#  'ridiculus',
#  'Fusce',
#  'ultricies',
#  'suscipit.',
#  'Donec',
#  'arcu',
#  'ullamcorper',
#  'iaculis.',
#  'auctor,',
#  'orci',
#  'auctor',
#  'vehicula.',
#  'nunc',
#  'lacinia',
#  'ullamcorper',
#  'lacinia.',
#  'condimentum.',
#  'ac',
#  'condimentum',
#  'facilisis',
#  'vehicula',
#  'dictum',
#  'tincidunt',
#  'ac',
#  'nec',
#  'consectetur',
#  'consequat',
#  'placerat',
#  'faucibus',
#  'faucibus',
#  'accumsan,',
#  'Nunc',
#  'congue',
#  'consectetur.',
#  'Orci',
#  'nascetur',
#  'ridiculus',
#  'Donec',
#  'congue',
#  'scelerisque',
#  'placerat',
#  'ultrices',
#  'lectus',
#  'congue',
#  'nec,',
#  'tincidunt',
#  'arcu.',
#  'ultricies',
#  'ac',
#  'lacus',
#  'cursus',
#  'auctor',
#  'vehicula',
#  'scelerisque',
#  'orci.',
#  'nec',
#  'Orci',
#  'nascetur',
#  'ridiculus',
#  'ultrices',
#  'lectus',
#  'consectetur',
#  'faucibus',
#  'Maecenas',
#  'iaculis',
#  'nunc',
#  'nec',
#  'orci',
#  'accumsan',
#  'ac',
#  'convallis',
#  'consectetur',
#  'lacus',
#  'congue.',
#  'cursus,',
#  'arcu',
#  'cursus,',
#  'arcu,',
#  'ultricies',
#  'Donec',
#  'ullamcorper',
#  'luctus',
#  'scelerisque,',
#  'lectus',
#  'consequat',
#  'nec',
#  'commodo.',
#  'iaculis',
#  'dictum',
#  'tincidunt',
#  'rhoncus.',
#  'Maecenas',
#  'Maecenas',
#  'suscipit',
#  'lacinia.',
#  'ultricies',
#  'condimentum.',
#  'Donec',
#  'facilisis',
#  'facilisis',
#  'orci,',
#  'consectetur',
#  'adipiscing',
#  'nec',
#  'sollicitudin.',
#  'Fusce',
#  'orci.',
#  'convallis.',
#  'consectetur',
#  'congue',
#  'tincidunt',
#  'faucibus',
#  'nunc',
#  'tincidunt',
#  'ultrices.',
#  'Fusce',
#  'efficitur',
#  'ultrices.',
#  'lacinia',
#  'dictum',
#  'lectus',
#  'nunc',
#  'scelerisque',
#  'facilisi.',
#  'vehicula,',
#  'faucibus',
#  'lacus',
#  'rhoncus',
#  'scelerisque',
#  'efficitur',
#  'consectetur.',
#  'cursus.',
#  'ullamcorper',
#  'tincidunt',
#  'Maecenas',
#  'sollicitudin',
#  'Donec',
#  'auctor',
#  'tincidunt',
#  'Donec',
#  'facilisis',
#  'faucibus',
#  'orci',
#  'nec',
#  'lectus',
#  'Maecenas',
#  'efficitur',
#  'lectus,',
#  'convallis',
#  'ac',
#  'orci.',
#  'Fusce',
#  'tincidunt,',
#  'commodo',
#  'scelerisque',
#  'Maecenas',
#  'scelerisque',
#  'luctus',
#  'faucibus',
#  'auctor,',
#  'lectus',
#  'nunc',
#  'convallis',
#  'suscipit',
#  'Fusce',
#  'orci',
#  'lacus',
#  'cursus',
#  'lacus',
#  'convallis',
#  'tincidunt',
#  'lacus',
#  'ac',
#  'faucibus',
#  'Donec',
#  'faucibus',
#  'orci',
#  'luctus',
#  'ultrices',
#  'cubilia',
#  'rhoncus',
#  'ac',
#  'scelerisque',
#  'auctor',
#  'auctor',
#  'accumsan',
#  'consequat,',
#  'suscipit,',
#  'lacus',
#  'arcu.',
#  'Fusce',
#  'dictum,',
#  'nec',
#  'iaculis',
#  'vehicula',
#  'accumsan',
#  'nunc',
#  'lectus,',
#  'ac',
#  'auctor',
#  'nec',
#  'ac',
#  'ac',
#  'condimentum.',
#  'faucibus',
#  'placerat',
#  'ac',
#  'consequat',
#  'ac,',
#  'tincidunt',
#  'convallis',
#  'sollicitudin',
#  'lacus.',
#  'Nunc',
#  'consectetur,',
#  'consequat,',
#  'arcu',
#  'faucibus',
#  'facilisis',
#  'luctus',
#  'suscipit',
#  'faucibus',
#  'nec',
#  'consectetur',
#  'sollicitudin',
#  'Donec',
#  'ac',
#  'luctus',
#  'nunc,',
#  'nec',
#  'ac',
#  'tincidunt.',
#  'Fusce',
#  'lacus',
#  'Donec',
#  'dictum',
#  'condimentum',
#  'luctus',
#  'faucibus,',
#  'ultrices',
#  'ac',
#  'faucibus.',
#  'vehicula',
#  'efficitur',
#  'convallis',
#  'faucibus',
#  'lectus.',
#  'facilisis',
#  'Maecenas',
#  'Donec',
#  'placerat,',
#  'accumsan,',
#  'lectus',
#  'nec',
#  'efficitur',
#  'ac',
#  'arcu',
#  'lectus',
#  'dictum',
#  'ullamcorper',
#  'Nunc',
#  'ac',
#  'orci',
#  'consectetur',
#  'ac',
#  'lacus.',
#  'Donec',
#  'lacinia',
#  'Nunc',
#  'tincidunt',
#  'cursus',
#  'congue',
#  'commodo,',
#  'tincidunt',
#  'ullamcorper',
#  'ultricies',
#  'ullamcorper',
#  'placerat',
#  'orci.',
#  'arcu.',
#  'accumsan',
#  'hac',
#  'dictumst.',
#  'tincidunt',
#  'rhoncus',
#  'lacus.',
#  'nec',
#  'facilisis',
#  'ultrices',
#  'Nunc',
#  'placerat',
#  'ultrices',
#  'orci',
#  'ac',
#  'consequat',
#  'ultricies',
#  'lectus',
#  'lectus',
#  'nec,',
#  'consequat.',
#  'facilisis',
#  'orci',
#  'arcu',
#  'lacinia.',
#  'Fusce',
#  'ultrices',
#  'commodo',
#  'scelerisque',
#  'suscipit',
#  'commodo,',
#  'iaculis.',
#  'nunc',
#  'ultricies',
#  'sollicitudin',
#  'congue',
#  'lacus',
#  'tincidunt.',
#  'scelerisque',
#  'arcu,',
#  'consectetur',
#  'ultricies',
#  'orci',
#  'efficitur',
#  'congue.',
#  'nunc',
#  'commodo',
#  'arcu.',
#  'consequat',
#  'orci,',
#  'tincidunt',
#  'scelerisque',
#  'rhoncus',
#  'efficitur',
#  'Nunc',
#  'nunc',
#  'ultrices',
#  'ultricies',
#  'luctus.',
#  'Fusce',
#  'luctus',
#  'Donec',
#  'lacinia',
#  'arcu',
#  'rhoncus.',
#  'facilisi.',
#  'Fusce',
#  'efficitur',
#  'scelerisque',
#  'dictum',
#  'luctus.',
#  'sollicitudin',
#  'ac',
#  'faucibus.',
#  'lacinia',
#  'suscipit',
#  'ac',
#  'congue',
#  'consectetur',
#  'adipiscing',
#  'convallis',
#  'faucibus.',
#  'Donec',
#  'tincidunt',
#  'lacus',
#  'luctus',
#  'taciti',
#  'sociosqu',
#  'conubia',
#  'inceptos',
#  'vehicula',
#  'ullamcorper',
#  'rhoncus',
#  'placerat',
#  'orci',
#  'faucibus.',
#  'dictum',
#  'Fusce',
#  'luctus.',
#  'lacus',
#  'nec',
#  'commodo',
#  'lectus',
#  'consequat,',
#  'convallis',
#  'tincidunt',
#  'iaculis',
#  'suscipit',
#  'arcu,',
#  'ac,',
#  'ullamcorper',
#  'nec',
#  'condimentum',
#  'Nunc',
#  'iaculis',
#  'facilisis',
#  'Fusce',
#  'nec',
#  'nunc',
#  'vehicula',
#  'luctus,',
#  'vehicula',
#  'ac',
#  'arcu.',
#  'tincidunt',
#  'consequat.',
#  'condimentum',
#  'nunc',
#  'consectetur',
#  'suscipit',
#  'efficitur',
#  'lacus.',
#  'Donec',
#  'lacus',
#  'congue.',
#  'dictum',
#  'facilisis',
#  'lacus',
#  'cursus.',
#  'ac',
#  'Fusce',
#  'vehicula',
#  'tincidunt',
#  'placerat.',
#  'consequat,',
#  'ac',
#  'rhoncus',
#  'suscipit.',
#  'nec',
#  'vehicula',
#  'condimentum',
#  'nec',
#  'lectus',
#  'tincidunt.',
#  'ac',
#  'arcu.',
#  'Maecenas',
#  'convallis',
#  'consectetur,',
#  'ac',
#  'auctor',
#  'lectus',
#  'vehicula',
#  'consequat',
#  'accumsan.',
#  'nunc',
#  'dictum.',
#  'rhoncus',
#  'lacus',
#  'scelerisque',
#  'nunc',
#  'placerat',
#  'ultricies,',
#  'rhoncus',
#  'placerat',
#  'nec',
#  'iaculis.',
#  'hac',
#  'dictumst.',
#  'sollicitudin',
#  'lectus',
#  'efficitur',
#  'nec',
#  'ultricies,',
#  'lectus',
#  'tincidunt.',
#  'orci',
#  'placerat',
#  'auctor.',
#  'luctus',
#  'lacus',
#  'iaculis,',
#  'rhoncus',
#  'condimentum.',
#  'orci',
#  'accumsan',
#  'scelerisque,',
#  'sollicitudin',
#  'dictum',
#  ...]

# %% [markdown]
# ## La Transformation distinct()
# ![image.png](attachment:image.png)

# %%
wordRdd.count()
# Out:
# 13507

# %%
wordRdd.distinct().count()
# Out:
# 466

# %% [markdown]
# ## La Transformation union()
#
# ![image.png](attachment:image.png)

# %%
numRdd1 = sc.parallelize([1,7,9,4,10,15])
numRdd2 = sc.parallelize([2,1,5,10])
numRdd2.union(numRdd1).collect()
# Out:
# [2, 1, 5, 10, 1, 7, 9, 4, 10, 15]

# %% [markdown]
# ## La Transformation reduceByKey
# ![image.png](attachment:image.png)

# %%
data = sc.parallelize([(1,2),(3,4),(3,6),(3,4)])
data.collect()
# Out:
# [(1, 2), (3, 4), (3, 6), (3, 4)]

# %%
data.reduceByKey(lambda x, y : x+y).collect()
# Out:
# [(1, 2), (3, 14)]

# %%
x = sc.parallelize([("a", 1), ("b", 40)])
y = sc.parallelize([("a", 2), ("b", 10)])
x.union(y).reduceByKey(lambda a,b: a/b).collect()
# Out:
# [('b', 4.0), ('a', 0.5)]

# %% [markdown]
# ## Join()

# %%
x = sc.parallelize([("a", 1), ("b", 40)])
y = sc.parallelize([("a", 2), ("b", 10)])
x.join(y).collect()
# Out:
# [('b', (40, 10)), ('a', (1, 2))]

# %% [markdown]
# ## La Transformation mapValues()

# %%
data = sc.parallelize([(1,2),(3,4),(3,6),(3,4)])
data.collect()
# Out:
# [(1, 2), (3, 4), (3, 6), (3, 4)]

# %%
data.mapValues(lambda x: x/2).collect()
# Out:
# [(1, 1.0), (3, 2.0), (3, 3.0), (3, 2.0)]
